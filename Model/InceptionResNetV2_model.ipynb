# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Aditya1Jhaveri/cervix-cancer-Deep-learning.git
# Out:
# Cloning into 'cervix-cancer-Deep-learning'...
# remote: Enumerating objects: 53268, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 53268 (delta 4), reused 33 (delta 3), pack-reused 53234
# Receiving objects: 100% (53268/53268), 1.75 GiB | 40.11 MiB/s, done.
# Resolving deltas: 100% (210/210), done.
# Updating files: 100% (50894/50894), done.

# %%
import tensorflow as tf
from keras.applications import InceptionResNetV2
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization,Flatten
from keras.models import Model
from keras.optimizers import RMSprop
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn import preprocessing
from keras.utils import to_categorical



# Set your data directories and parameters
train_data_dir = '/content/cervix-cancer-Deep-learning/NEW_DATASET/train'
test_data_dir = '/content/cervix-cancer-Deep-learning/NEW_DATASET/test'
val_data_dir = '/content/cervix-cancer-Deep-learning/NEW_DATASET/validation'


img_width, img_height = 224, 224
batch_size = 16
base_learning_rate = 0.001  # Adjust as needed

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2,
    fill_mode='nearest'
)

# Data preprocessing for test
test_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2,
    fill_mode='nearest'
)

# Load the data using data generators
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',  # Automatically one-hot encodes labels
    shuffle=True  # Shuffle the data
)
print(f"Found {train_generator.samples} images belonging to {len(train_generator.class_indices)} classes in train dataset.")

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',  # Automatically one-hot encodes labels
    shuffle=False  # No need to shuffle test data
)
print(f"Found {test_generator.samples} images belonging to {len(test_generator.class_indices)} classes in test dataset.")

val_generator = val_datagen.flow_from_directory(
    val_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',  # Automatically one-hot encodes labels
    shuffle=False  # No need to shuffle test data
)
print(f"Found {val_generator.samples} images belonging to {len(val_generator.class_indices)} classes in validation dataset.")
# Out:
# Found 12110 images belonging to 7 classes.
# Found 12110 images belonging to 7 classes in train dataset.
# Found 2083 images belonging to 7 classes.
# Found 2083 images belonging to 7 classes in test dataset.
# Found 3111 images belonging to 7 classes.
# Found 3111 images belonging to 7 classes in validation dataset.

# %%
# Load the InceptionResNetV2 model
base_model = InceptionResNetV2(include_top=False, weights='imagenet', input_shape=(224, 224, 3))


# Add your custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)
# x = Dropout(0.5)(x)
x = Flatten()(x)

x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
# x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
# x = BatchNormalization()(x)

predictions = Dense(train_generator.num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)


base_model.trainable = True

set_trainable = False

for layer in base_model.layers:
  if layer.name == 'block8_2_conv':
    set_trainable = True
  if set_trainable:
    layer.trainable = True
  else:
    layer.trainable = False

for layer in base_model.layers:
  print(layer.name,layer.trainable)
# Out:
# input_13 False
# conv2d_1267 False
# batch_normalization_1291 False
# activation_1267 False
# conv2d_1268 False
# batch_normalization_1292 False
# activation_1268 False
# conv2d_1269 False
# batch_normalization_1293 False
# activation_1269 False
# max_pooling2d_40 False
# conv2d_1270 False
# batch_normalization_1294 False
# activation_1270 False
# conv2d_1271 False
# batch_normalization_1295 False
# activation_1271 False
# max_pooling2d_41 False
# conv2d_1275 False
# batch_normalization_1299 False
# activation_1275 False
# conv2d_1273 False
# conv2d_1276 False
# batch_normalization_1297 False
# batch_normalization_1300 False
# activation_1273 False
# activation_1276 False
# average_pooling2d_66 False
# conv2d_1272 False
# conv2d_1274 False
# conv2d_1277 False
# conv2d_1278 False
# batch_normalization_1296 False
# batch_normalization_1298 False
# batch_normalization_1301 False
# batch_normalization_1302 False
# activation_1272 False
# activation_1274 False
# activation_1277 False
# activation_1278 False
# mixed_5b False
# conv2d_1282 False
# batch_normalization_1306 False
# activation_1282 False
# conv2d_1280 False
# conv2d_1283 False
# batch_normalization_1304 False
# batch_normalization_1307 False
# activation_1280 False
# activation_1283 False
# conv2d_1279 False
# conv2d_1281 False
# conv2d_1284 False
# batch_normalization_1303 False
# batch_normalization_1305 False
# batch_normalization_1308 False
# activation_1279 False
# activation_1281 False
# activation_1284 False
# block35_1_mixed False
# block35_1_conv False
# custom_scale_layer_120 False
# block35_1_ac False
# conv2d_1288 False
# batch_normalization_1312 False
# activation_1288 False
# conv2d_1286 False
# conv2d_1289 False
# batch_normalization_1310 False
# batch_normalization_1313 False
# activation_1286 False
# activation_1289 False
# conv2d_1285 False
# conv2d_1287 False
# conv2d_1290 False
# batch_normalization_1309 False
# batch_normalization_1311 False
# batch_normalization_1314 False
# activation_1285 False
# activation_1287 False
# activation_1290 False
# block35_2_mixed False
# block35_2_conv False
# custom_scale_layer_121 False
# block35_2_ac False
# conv2d_1294 False
# batch_normalization_1318 False
# activation_1294 False
# conv2d_1292 False
# conv2d_1295 False
# batch_normalization_1316 False
# batch_normalization_1319 False
# activation_1292 False
# activation_1295 False
# conv2d_1291 False
# conv2d_1293 False
# conv2d_1296 False
# batch_normalization_1315 False
# batch_normalization_1317 False
# batch_normalization_1320 False
# activation_1291 False
# activation_1293 False
# activation_1296 False
# block35_3_mixed False
# block35_3_conv False
# custom_scale_layer_122 False
# block35_3_ac False
# conv2d_1300 False
# batch_normalization_1324 False
# activation_1300 False
# conv2d_1298 False
# conv2d_1301 False
# batch_normalization_1322 False
# batch_normalization_1325 False
# activation_1298 False
# activation_1301 False
# conv2d_1297 False
# conv2d_1299 False
# conv2d_1302 False
# batch_normalization_1321 False
# batch_normalization_1323 False
# batch_normalization_1326 False
# activation_1297 False
# activation_1299 False
# activation_1302 False
# block35_4_mixed False
# block35_4_conv False
# custom_scale_layer_123 False
# block35_4_ac False
# conv2d_1306 False
# batch_normalization_1330 False
# activation_1306 False
# conv2d_1304 False
# conv2d_1307 False
# batch_normalization_1328 False
# batch_normalization_1331 False
# activation_1304 False
# activation_1307 False
# conv2d_1303 False
# conv2d_1305 False
# conv2d_1308 False
# batch_normalization_1327 False
# batch_normalization_1329 False
# batch_normalization_1332 False
# activation_1303 False
# activation_1305 False
# activation_1308 False
# block35_5_mixed False
# block35_5_conv False
# custom_scale_layer_124 False
# block35_5_ac False
# conv2d_1312 False
# batch_normalization_1336 False
# activation_1312 False
# conv2d_1310 False
# conv2d_1313 False
# batch_normalization_1334 False
# batch_normalization_1337 False
# activation_1310 False
# activation_1313 False
# conv2d_1309 False
# conv2d_1311 False
# conv2d_1314 False
# batch_normalization_1333 False
# batch_normalization_1335 False
# batch_normalization_1338 False
# activation_1309 False
# activation_1311 False
# activation_1314 False
# block35_6_mixed False
# block35_6_conv False
# custom_scale_layer_125 False
# block35_6_ac False
# conv2d_1318 False
# batch_normalization_1342 False
# activation_1318 False
# conv2d_1316 False
# conv2d_1319 False
# batch_normalization_1340 False
# batch_normalization_1343 False
# activation_1316 False
# activation_1319 False
# conv2d_1315 False
# conv2d_1317 False
# conv2d_1320 False
# batch_normalization_1339 False
# batch_normalization_1341 False
# batch_normalization_1344 False
# activation_1315 False
# activation_1317 False
# activation_1320 False
# block35_7_mixed False
# block35_7_conv False
# custom_scale_layer_126 False
# block35_7_ac False
# conv2d_1324 False
# batch_normalization_1348 False
# activation_1324 False
# conv2d_1322 False
# conv2d_1325 False
# batch_normalization_1346 False
# batch_normalization_1349 False
# activation_1322 False
# activation_1325 False
# conv2d_1321 False
# conv2d_1323 False
# conv2d_1326 False
# batch_normalization_1345 False
# batch_normalization_1347 False
# batch_normalization_1350 False
# activation_1321 False
# activation_1323 False
# activation_1326 False
# block35_8_mixed False
# block35_8_conv False
# custom_scale_layer_127 False
# block35_8_ac False
# conv2d_1330 False
# batch_normalization_1354 False
# activation_1330 False
# conv2d_1328 False
# conv2d_1331 False
# batch_normalization_1352 False
# batch_normalization_1355 False
# activation_1328 False
# activation_1331 False
# conv2d_1327 False
# conv2d_1329 False
# conv2d_1332 False
# batch_normalization_1351 False
# batch_normalization_1353 False
# batch_normalization_1356 False
# activation_1327 False
# activation_1329 False
# activation_1332 False
# block35_9_mixed False
# block35_9_conv False
# custom_scale_layer_128 False
# block35_9_ac False
# conv2d_1336 False
# batch_normalization_1360 False
# activation_1336 False
# conv2d_1334 False
# conv2d_1337 False
# batch_normalization_1358 False
# batch_normalization_1361 False
# activation_1334 False
# activation_1337 False
# conv2d_1333 False
# conv2d_1335 False
# conv2d_1338 False
# batch_normalization_1357 False
# batch_normalization_1359 False
# batch_normalization_1362 False
# activation_1333 False
# activation_1335 False
# activation_1338 False
# block35_10_mixed False
# block35_10_conv False
# custom_scale_layer_129 False
# block35_10_ac False
# conv2d_1340 False
# batch_normalization_1364 False
# activation_1340 False
# conv2d_1341 False
# batch_normalization_1365 False
# activation_1341 False
# conv2d_1339 False
# conv2d_1342 False
# batch_normalization_1363 False
# batch_normalization_1366 False
# activation_1339 False
# activation_1342 False
# max_pooling2d_42 False
# mixed_6a False
# conv2d_1344 False
# batch_normalization_1368 False
# activation_1344 False
# conv2d_1345 False
# batch_normalization_1369 False
# activation_1345 False
# conv2d_1343 False
# conv2d_1346 False
# batch_normalization_1367 False
# batch_normalization_1370 False
# activation_1343 False
# activation_1346 False
# block17_1_mixed False
# block17_1_conv False
# custom_scale_layer_130 False
# block17_1_ac False
# conv2d_1348 False
# batch_normalization_1372 False
# activation_1348 False
# conv2d_1349 False
# batch_normalization_1373 False
# activation_1349 False
# conv2d_1347 False
# conv2d_1350 False
# batch_normalization_1371 False
# batch_normalization_1374 False
# activation_1347 False
# activation_1350 False
# block17_2_mixed False
# block17_2_conv False
# custom_scale_layer_131 False
# block17_2_ac False
# conv2d_1352 False
# batch_normalization_1376 False
# activation_1352 False
# conv2d_1353 False
# batch_normalization_1377 False
# activation_1353 False
# conv2d_1351 False
# conv2d_1354 False
# batch_normalization_1375 False
# batch_normalization_1378 False
# activation_1351 False
# activation_1354 False
# block17_3_mixed False
# block17_3_conv False
# custom_scale_layer_132 False
# block17_3_ac False
# conv2d_1356 False
# batch_normalization_1380 False
# activation_1356 False
# conv2d_1357 False
# batch_normalization_1381 False
# activation_1357 False
# conv2d_1355 False
# conv2d_1358 False
# batch_normalization_1379 False
# batch_normalization_1382 False
# activation_1355 False
# activation_1358 False
# block17_4_mixed False
# block17_4_conv False
# custom_scale_layer_133 False
# block17_4_ac False
# conv2d_1360 False
# batch_normalization_1384 False
# activation_1360 False
# conv2d_1361 False
# batch_normalization_1385 False
# activation_1361 False
# conv2d_1359 False
# conv2d_1362 False
# batch_normalization_1383 False
# batch_normalization_1386 False
# activation_1359 False
# activation_1362 False
# block17_5_mixed False
# block17_5_conv False
# custom_scale_layer_134 False
# block17_5_ac False
# conv2d_1364 False
# batch_normalization_1388 False
# activation_1364 False
# conv2d_1365 False
# batch_normalization_1389 False
# activation_1365 False
# conv2d_1363 False
# conv2d_1366 False
# batch_normalization_1387 False
# batch_normalization_1390 False
# activation_1363 False
# activation_1366 False
# block17_6_mixed False
# block17_6_conv False
# custom_scale_layer_135 False
# block17_6_ac False
# conv2d_1368 False
# batch_normalization_1392 False
# activation_1368 False
# conv2d_1369 False
# batch_normalization_1393 False
# activation_1369 False
# conv2d_1367 False
# conv2d_1370 False
# batch_normalization_1391 False
# batch_normalization_1394 False
# activation_1367 False
# activation_1370 False
# block17_7_mixed False
# block17_7_conv False
# custom_scale_layer_136 False
# block17_7_ac False
# conv2d_1372 False
# batch_normalization_1396 False
# activation_1372 False
# conv2d_1373 False
# batch_normalization_1397 False
# activation_1373 False
# conv2d_1371 False
# conv2d_1374 False
# batch_normalization_1395 False
# batch_normalization_1398 False
# activation_1371 False
# activation_1374 False
# block17_8_mixed False
# block17_8_conv False
# custom_scale_layer_137 False
# block17_8_ac False
# conv2d_1376 False
# batch_normalization_1400 False
# activation_1376 False
# conv2d_1377 False
# batch_normalization_1401 False
# activation_1377 False
# conv2d_1375 False
# conv2d_1378 False
# batch_normalization_1399 False
# batch_normalization_1402 False
# activation_1375 False
# activation_1378 False
# block17_9_mixed False
# block17_9_conv False
# custom_scale_layer_138 False
# block17_9_ac False
# conv2d_1380 False
# batch_normalization_1404 False
# activation_1380 False
# conv2d_1381 False
# batch_normalization_1405 False
# activation_1381 False
# conv2d_1379 False
# conv2d_1382 False
# batch_normalization_1403 False
# batch_normalization_1406 False
# activation_1379 False
# activation_1382 False
# block17_10_mixed False
# block17_10_conv False
# custom_scale_layer_139 False
# block17_10_ac False
# conv2d_1384 False
# batch_normalization_1408 False
# activation_1384 False
# conv2d_1385 False
# batch_normalization_1409 False
# activation_1385 False
# conv2d_1383 False
# conv2d_1386 False
# batch_normalization_1407 False
# batch_normalization_1410 False
# activation_1383 False
# activation_1386 False
# block17_11_mixed False
# block17_11_conv False
# custom_scale_layer_140 False
# block17_11_ac False
# conv2d_1388 False
# batch_normalization_1412 False
# activation_1388 False
# conv2d_1389 False
# batch_normalization_1413 False
# activation_1389 False
# conv2d_1387 False
# conv2d_1390 False
# batch_normalization_1411 False
# batch_normalization_1414 False
# activation_1387 False
# activation_1390 False
# block17_12_mixed False
# block17_12_conv False
# custom_scale_layer_141 False
# block17_12_ac False
# conv2d_1392 False
# batch_normalization_1416 False
# activation_1392 False
# conv2d_1393 False
# batch_normalization_1417 False
# activation_1393 False
# conv2d_1391 False
# conv2d_1394 False
# batch_normalization_1415 False
# batch_normalization_1418 False
# activation_1391 False
# activation_1394 False
# block17_13_mixed False
# block17_13_conv False
# custom_scale_layer_142 False
# block17_13_ac False
# conv2d_1396 False
# batch_normalization_1420 False
# activation_1396 False
# conv2d_1397 False
# batch_normalization_1421 False
# activation_1397 False
# conv2d_1395 False
# conv2d_1398 False
# batch_normalization_1419 False
# batch_normalization_1422 False
# activation_1395 False
# activation_1398 False
# block17_14_mixed False
# block17_14_conv False
# custom_scale_layer_143 False
# block17_14_ac False
# conv2d_1400 False
# batch_normalization_1424 False
# activation_1400 False
# conv2d_1401 False
# batch_normalization_1425 False
# activation_1401 False
# conv2d_1399 False
# conv2d_1402 False
# batch_normalization_1423 False
# batch_normalization_1426 False
# activation_1399 False
# activation_1402 False
# block17_15_mixed False
# block17_15_conv False
# custom_scale_layer_144 False
# block17_15_ac False
# conv2d_1404 False
# batch_normalization_1428 False
# activation_1404 False
# conv2d_1405 False
# batch_normalization_1429 False
# activation_1405 False
# conv2d_1403 False
# conv2d_1406 False
# batch_normalization_1427 False
# batch_normalization_1430 False
# activation_1403 False
# activation_1406 False
# block17_16_mixed False
# block17_16_conv False
# custom_scale_layer_145 False
# block17_16_ac False
# conv2d_1408 False
# batch_normalization_1432 False
# activation_1408 False
# conv2d_1409 False
# batch_normalization_1433 False
# activation_1409 False
# conv2d_1407 False
# conv2d_1410 False
# batch_normalization_1431 False
# batch_normalization_1434 False
# activation_1407 False
# activation_1410 False
# block17_17_mixed False
# block17_17_conv False
# custom_scale_layer_146 False
# block17_17_ac False
# conv2d_1412 False
# batch_normalization_1436 False
# activation_1412 False
# conv2d_1413 False
# batch_normalization_1437 False
# activation_1413 False
# conv2d_1411 False
# conv2d_1414 False
# batch_normalization_1435 False
# batch_normalization_1438 False
# activation_1411 False
# activation_1414 False
# block17_18_mixed False
# block17_18_conv False
# custom_scale_layer_147 False
# block17_18_ac False
# conv2d_1416 False
# batch_normalization_1440 False
# activation_1416 False
# conv2d_1417 False
# batch_normalization_1441 False
# activation_1417 False
# conv2d_1415 False
# conv2d_1418 False
# batch_normalization_1439 False
# batch_normalization_1442 False
# activation_1415 False
# activation_1418 False
# block17_19_mixed False
# block17_19_conv False
# custom_scale_layer_148 False
# block17_19_ac False
# conv2d_1420 False
# batch_normalization_1444 False
# activation_1420 False
# conv2d_1421 False
# batch_normalization_1445 False
# activation_1421 False
# conv2d_1419 False
# conv2d_1422 False
# batch_normalization_1443 False
# batch_normalization_1446 False
# activation_1419 False
# activation_1422 False
# block17_20_mixed False
# block17_20_conv False
# custom_scale_layer_149 False
# block17_20_ac False
# conv2d_1427 False
# batch_normalization_1451 False
# activation_1427 False
# conv2d_1423 False
# conv2d_1425 False
# conv2d_1428 False
# batch_normalization_1447 False
# batch_normalization_1449 False
# batch_normalization_1452 False
# activation_1423 False
# activation_1425 False
# activation_1428 False
# conv2d_1424 False
# conv2d_1426 False
# conv2d_1429 False
# batch_normalization_1448 False
# batch_normalization_1450 False
# batch_normalization_1453 False
# activation_1424 False
# activation_1426 False
# activation_1429 False
# max_pooling2d_43 False
# mixed_7a False
# conv2d_1431 False
# batch_normalization_1455 False
# activation_1431 False
# conv2d_1432 False
# batch_normalization_1456 False
# activation_1432 False
# conv2d_1430 False
# conv2d_1433 False
# batch_normalization_1454 False
# batch_normalization_1457 False
# activation_1430 False
# activation_1433 False
# block8_1_mixed False
# block8_1_conv False
# custom_scale_layer_150 False
# block8_1_ac False
# conv2d_1435 False
# batch_normalization_1459 False
# activation_1435 False
# conv2d_1436 False
# batch_normalization_1460 False
# activation_1436 False
# conv2d_1434 False
# conv2d_1437 False
# batch_normalization_1458 False
# batch_normalization_1461 False
# activation_1434 False
# activation_1437 False
# block8_2_mixed False
# block8_2_conv True
# custom_scale_layer_151 True
# block8_2_ac True
# conv2d_1439 True
# batch_normalization_1463 True
# activation_1439 True
# conv2d_1440 True
# batch_normalization_1464 True
# activation_1440 True
# conv2d_1438 True
# conv2d_1441 True
# batch_normalization_1462 True
# batch_normalization_1465 True
# activation_1438 True
# activation_1441 True
# block8_3_mixed True
# block8_3_conv True
# custom_scale_layer_152 True
# block8_3_ac True
# conv2d_1443 True
# batch_normalization_1467 True
# activation_1443 True
# conv2d_1444 True
# batch_normalization_1468 True
# activation_1444 True
# conv2d_1442 True
# conv2d_1445 True
# batch_normalization_1466 True
# batch_normalization_1469 True
# activation_1442 True
# activation_1445 True
# block8_4_mixed True
# block8_4_conv True
# custom_scale_layer_153 True
# block8_4_ac True
# conv2d_1447 True
# batch_normalization_1471 True
# activation_1447 True
# conv2d_1448 True
# batch_normalization_1472 True
# activation_1448 True
# conv2d_1446 True
# conv2d_1449 True
# batch_normalization_1470 True
# batch_normalization_1473 True
# activation_1446 True
# activation_1449 True
# block8_5_mixed True
# block8_5_conv True
# custom_scale_layer_154 True
# block8_5_ac True
# conv2d_1451 True
# batch_normalization_1475 True
# activation_1451 True
# conv2d_1452 True
# batch_normalization_1476 True
# activation_1452 True
# conv2d_1450 True
# conv2d_1453 True
# batch_normalization_1474 True
# batch_normalization_1477 True
# activation_1450 True
# activation_1453 True
# block8_6_mixed True
# block8_6_conv True
# custom_scale_layer_155 True
# block8_6_ac True
# conv2d_1455 True
# batch_normalization_1479 True
# activation_1455 True
# conv2d_1456 True
# batch_normalization_1480 True
# activation_1456 True
# conv2d_1454 True
# conv2d_1457 True
# batch_normalization_1478 True
# batch_normalization_1481 True
# activation_1454 True
# activation_1457 True
# block8_7_mixed True
# block8_7_conv True
# custom_scale_layer_156 True
# block8_7_ac True
# conv2d_1459 True
# batch_normalization_1483 True
# activation_1459 True
# conv2d_1460 True
# batch_normalization_1484 True
# activation_1460 True
# conv2d_1458 True
# conv2d_1461 True
# batch_normalization_1482 True
# batch_normalization_1485 True
# activation_1458 True
# activation_1461 True
# block8_8_mixed True
# block8_8_conv True
# custom_scale_layer_157 True
# block8_8_ac True
# conv2d_1463 True
# batch_normalization_1487 True
# activation_1463 True
# conv2d_1464 True
# batch_normalization_1488 True
# activation_1464 True
# conv2d_1462 True
# conv2d_1465 True
# batch_normalization_1486 True
# batch_normalization_1489 True
# activation_1462 True
# activation_1465 True
# block8_9_mixed True
# block8_9_conv True
# custom_scale_layer_158 True
# block8_9_ac True
# conv2d_1467 True
# batch_normalization_1491 True
# activation_1467 True
# conv2d_1468 True
# batch_normalization_1492 True
# activation_1468 True
# conv2d_1466 True
# conv2d_1469 True
# batch_normalization_1490 True
# batch_normalization_1493 True
# activation_1466 True
# activation_1469 True
# block8_10_mixed True
# block8_10_conv True
# custom_scale_layer_159 True
# conv_7b True
# conv_7b_bn True
# conv_7b_ac True

# %%
model.summary();
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_861 (Conv2D)         (None, 111, 111, 32)         864       ['input_11[0][0]']
#
#  batch_normalization_881 (B  (None, 111, 111, 32)         96        ['conv2d_861[0][0]']
#  atchNormalization)
#
#  activation_861 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_881[0][0
#  )                                                                  ]']
#
#  conv2d_862 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_861[0][0]']
#
#  batch_normalization_882 (B  (None, 109, 109, 32)         96        ['conv2d_862[0][0]']
#  atchNormalization)
#
#  activation_862 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_882[0][0
#  )                                                                  ]']
#
#  conv2d_863 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_862[0][0]']
#
#  batch_normalization_883 (B  (None, 109, 109, 64)         192       ['conv2d_863[0][0]']
#  atchNormalization)
#
#  activation_863 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_883[0][0
#  )                                                                  ]']
#
#  max_pooling2d_32 (MaxPooli  (None, 54, 54, 64)           0         ['activation_863[0][0]']
#  ng2D)
#
#  conv2d_864 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_32[0][0]']
#
#  batch_normalization_884 (B  (None, 54, 54, 80)           240       ['conv2d_864[0][0]']
#  atchNormalization)
#
#  activation_864 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_884[0][0
#  )                                                                  ]']
#
#  conv2d_865 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_864[0][0]']
#
#  batch_normalization_885 (B  (None, 52, 52, 192)          576       ['conv2d_865[0][0]']
#  atchNormalization)
#
#  activation_865 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_885[0][0
#  )                                                                  ]']
#
#  max_pooling2d_33 (MaxPooli  (None, 25, 25, 192)          0         ['activation_865[0][0]']
#  ng2D)
#
#  conv2d_869 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_33[0][0]']
#
#  batch_normalization_889 (B  (None, 25, 25, 64)           192       ['conv2d_869[0][0]']
#  atchNormalization)
#
#  activation_869 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_889[0][0
#  )                                                                  ]']
#
#  conv2d_867 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_33[0][0]']
#
#  conv2d_870 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_869[0][0]']
#
#  batch_normalization_887 (B  (None, 25, 25, 48)           144       ['conv2d_867[0][0]']
#  atchNormalization)
#
#  batch_normalization_890 (B  (None, 25, 25, 96)           288       ['conv2d_870[0][0]']
#  atchNormalization)
#
#  activation_867 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_887[0][0
#  )                                                                  ]']
#
#  activation_870 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_890[0][0
#  )                                                                  ]']
#
#  average_pooling2d_64 (Aver  (None, 25, 25, 192)          0         ['max_pooling2d_33[0][0]']
#  agePooling2D)
#
#  conv2d_866 (Conv2D)         (None, 25, 25, 96)           18432     ['max_pooling2d_33[0][0]']
#
#  conv2d_868 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_867[0][0]']
#
#  conv2d_871 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_870[0][0]']
#
#  conv2d_872 (Conv2D)         (None, 25, 25, 64)           12288     ['average_pooling2d_64[0][0]']
#
#  batch_normalization_886 (B  (None, 25, 25, 96)           288       ['conv2d_866[0][0]']
#  atchNormalization)
#
#  batch_normalization_888 (B  (None, 25, 25, 64)           192       ['conv2d_868[0][0]']
#  atchNormalization)
#
#  batch_normalization_891 (B  (None, 25, 25, 96)           288       ['conv2d_871[0][0]']
#  atchNormalization)
#
#  batch_normalization_892 (B  (None, 25, 25, 64)           192       ['conv2d_872[0][0]']
#  atchNormalization)
#
#  activation_866 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_886[0][0
#  )                                                                  ]']
#
#  activation_868 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_888[0][0
#  )                                                                  ]']
#
#  activation_871 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_891[0][0
#  )                                                                  ]']
#
#  activation_872 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_892[0][0
#  )                                                                  ]']
#
#  mixed_5b (Concatenate)      (None, 25, 25, 320)          0         ['activation_866[0][0]',
#                                                                      'activation_868[0][0]',
#                                                                      'activation_871[0][0]',
#                                                                      'activation_872[0][0]']
#
#  conv2d_876 (Conv2D)         (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_896 (B  (None, 25, 25, 32)           96        ['conv2d_876[0][0]']
#  atchNormalization)
#
#  activation_876 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_896[0][0
#  )                                                                  ]']
#
#  conv2d_874 (Conv2D)         (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_877 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_876[0][0]']
#
#  batch_normalization_894 (B  (None, 25, 25, 32)           96        ['conv2d_874[0][0]']
#  atchNormalization)
#
#  batch_normalization_897 (B  (None, 25, 25, 48)           144       ['conv2d_877[0][0]']
#  atchNormalization)
#
#  activation_874 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_894[0][0
#  )                                                                  ]']
#
#  activation_877 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_897[0][0
#  )                                                                  ]']
#
#  conv2d_873 (Conv2D)         (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_875 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_874[0][0]']
#
#  conv2d_878 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_877[0][0]']
#
#  batch_normalization_893 (B  (None, 25, 25, 32)           96        ['conv2d_873[0][0]']
#  atchNormalization)
#
#  batch_normalization_895 (B  (None, 25, 25, 32)           96        ['conv2d_875[0][0]']
#  atchNormalization)
#
#  batch_normalization_898 (B  (None, 25, 25, 64)           192       ['conv2d_878[0][0]']
#  atchNormalization)
#
#  activation_873 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_893[0][0
#  )                                                                  ]']
#
#  activation_875 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_895[0][0
#  )                                                                  ]']
#
#  activation_878 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_898[0][0
#  )                                                                  ]']
#
#  block35_1_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_873[0][0]',
#  te)                                                                 'activation_875[0][0]',
#                                                                      'activation_878[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_40 (Cus  (None, 25, 25, 320)          0         ['mixed_5b[0][0]',
#  tomScaleLayer)                                                      'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_40[0][0]'
#                                                                     ]
#
#  conv2d_882 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_902 (B  (None, 25, 25, 32)           96        ['conv2d_882[0][0]']
#  atchNormalization)
#
#  activation_882 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_902[0][0
#  )                                                                  ]']
#
#  conv2d_880 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_883 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_882[0][0]']
#
#  batch_normalization_900 (B  (None, 25, 25, 32)           96        ['conv2d_880[0][0]']
#  atchNormalization)
#
#  batch_normalization_903 (B  (None, 25, 25, 48)           144       ['conv2d_883[0][0]']
#  atchNormalization)
#
#  activation_880 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_900[0][0
#  )                                                                  ]']
#
#  activation_883 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_903[0][0
#  )                                                                  ]']
#
#  conv2d_879 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_881 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_880[0][0]']
#
#  conv2d_884 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_883[0][0]']
#
#  batch_normalization_899 (B  (None, 25, 25, 32)           96        ['conv2d_879[0][0]']
#  atchNormalization)
#
#  batch_normalization_901 (B  (None, 25, 25, 32)           96        ['conv2d_881[0][0]']
#  atchNormalization)
#
#  batch_normalization_904 (B  (None, 25, 25, 64)           192       ['conv2d_884[0][0]']
#  atchNormalization)
#
#  activation_879 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_899[0][0
#  )                                                                  ]']
#
#  activation_881 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_901[0][0
#  )                                                                  ]']
#
#  activation_884 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_904[0][0
#  )                                                                  ]']
#
#  block35_2_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_879[0][0]',
#  te)                                                                 'activation_881[0][0]',
#                                                                      'activation_884[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_41 (Cus  (None, 25, 25, 320)          0         ['block35_1_ac[0][0]',
#  tomScaleLayer)                                                      'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_41[0][0]'
#                                                                     ]
#
#  conv2d_888 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_908 (B  (None, 25, 25, 32)           96        ['conv2d_888[0][0]']
#  atchNormalization)
#
#  activation_888 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_908[0][0
#  )                                                                  ]']
#
#  conv2d_886 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_889 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_888[0][0]']
#
#  batch_normalization_906 (B  (None, 25, 25, 32)           96        ['conv2d_886[0][0]']
#  atchNormalization)
#
#  batch_normalization_909 (B  (None, 25, 25, 48)           144       ['conv2d_889[0][0]']
#  atchNormalization)
#
#  activation_886 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_906[0][0
#  )                                                                  ]']
#
#  activation_889 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_909[0][0
#  )                                                                  ]']
#
#  conv2d_885 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_887 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_886[0][0]']
#
#  conv2d_890 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_889[0][0]']
#
#  batch_normalization_905 (B  (None, 25, 25, 32)           96        ['conv2d_885[0][0]']
#  atchNormalization)
#
#  batch_normalization_907 (B  (None, 25, 25, 32)           96        ['conv2d_887[0][0]']
#  atchNormalization)
#
#  batch_normalization_910 (B  (None, 25, 25, 64)           192       ['conv2d_890[0][0]']
#  atchNormalization)
#
#  activation_885 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_905[0][0
#  )                                                                  ]']
#
#  activation_887 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_907[0][0
#  )                                                                  ]']
#
#  activation_890 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_910[0][0
#  )                                                                  ]']
#
#  block35_3_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_885[0][0]',
#  te)                                                                 'activation_887[0][0]',
#                                                                      'activation_890[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_42 (Cus  (None, 25, 25, 320)          0         ['block35_2_ac[0][0]',
#  tomScaleLayer)                                                      'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_42[0][0]'
#                                                                     ]
#
#  conv2d_894 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_914 (B  (None, 25, 25, 32)           96        ['conv2d_894[0][0]']
#  atchNormalization)
#
#  activation_894 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_914[0][0
#  )                                                                  ]']
#
#  conv2d_892 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_895 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_894[0][0]']
#
#  batch_normalization_912 (B  (None, 25, 25, 32)           96        ['conv2d_892[0][0]']
#  atchNormalization)
#
#  batch_normalization_915 (B  (None, 25, 25, 48)           144       ['conv2d_895[0][0]']
#  atchNormalization)
#
#  activation_892 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_912[0][0
#  )                                                                  ]']
#
#  activation_895 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_915[0][0
#  )                                                                  ]']
#
#  conv2d_891 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_893 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_892[0][0]']
#
#  conv2d_896 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_895[0][0]']
#
#  batch_normalization_911 (B  (None, 25, 25, 32)           96        ['conv2d_891[0][0]']
#  atchNormalization)
#
#  batch_normalization_913 (B  (None, 25, 25, 32)           96        ['conv2d_893[0][0]']
#  atchNormalization)
#
#  batch_normalization_916 (B  (None, 25, 25, 64)           192       ['conv2d_896[0][0]']
#  atchNormalization)
#
#  activation_891 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_911[0][0
#  )                                                                  ]']
#
#  activation_893 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_913[0][0
#  )                                                                  ]']
#
#  activation_896 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_916[0][0
#  )                                                                  ]']
#
#  block35_4_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_891[0][0]',
#  te)                                                                 'activation_893[0][0]',
#                                                                      'activation_896[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_43 (Cus  (None, 25, 25, 320)          0         ['block35_3_ac[0][0]',
#  tomScaleLayer)                                                      'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_43[0][0]'
#                                                                     ]
#
#  conv2d_900 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_920 (B  (None, 25, 25, 32)           96        ['conv2d_900[0][0]']
#  atchNormalization)
#
#  activation_900 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_920[0][0
#  )                                                                  ]']
#
#  conv2d_898 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_901 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_900[0][0]']
#
#  batch_normalization_918 (B  (None, 25, 25, 32)           96        ['conv2d_898[0][0]']
#  atchNormalization)
#
#  batch_normalization_921 (B  (None, 25, 25, 48)           144       ['conv2d_901[0][0]']
#  atchNormalization)
#
#  activation_898 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_918[0][0
#  )                                                                  ]']
#
#  activation_901 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_921[0][0
#  )                                                                  ]']
#
#  conv2d_897 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_899 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_898[0][0]']
#
#  conv2d_902 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_901[0][0]']
#
#  batch_normalization_917 (B  (None, 25, 25, 32)           96        ['conv2d_897[0][0]']
#  atchNormalization)
#
#  batch_normalization_919 (B  (None, 25, 25, 32)           96        ['conv2d_899[0][0]']
#  atchNormalization)
#
#  batch_normalization_922 (B  (None, 25, 25, 64)           192       ['conv2d_902[0][0]']
#  atchNormalization)
#
#  activation_897 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_917[0][0
#  )                                                                  ]']
#
#  activation_899 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_919[0][0
#  )                                                                  ]']
#
#  activation_902 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_922[0][0
#  )                                                                  ]']
#
#  block35_5_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_897[0][0]',
#  te)                                                                 'activation_899[0][0]',
#                                                                      'activation_902[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_44 (Cus  (None, 25, 25, 320)          0         ['block35_4_ac[0][0]',
#  tomScaleLayer)                                                      'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_44[0][0]'
#                                                                     ]
#
#  conv2d_906 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_926 (B  (None, 25, 25, 32)           96        ['conv2d_906[0][0]']
#  atchNormalization)
#
#  activation_906 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_926[0][0
#  )                                                                  ]']
#
#  conv2d_904 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_907 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_906[0][0]']
#
#  batch_normalization_924 (B  (None, 25, 25, 32)           96        ['conv2d_904[0][0]']
#  atchNormalization)
#
#  batch_normalization_927 (B  (None, 25, 25, 48)           144       ['conv2d_907[0][0]']
#  atchNormalization)
#
#  activation_904 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_924[0][0
#  )                                                                  ]']
#
#  activation_907 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_927[0][0
#  )                                                                  ]']
#
#  conv2d_903 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_905 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_904[0][0]']
#
#  conv2d_908 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_907[0][0]']
#
#  batch_normalization_923 (B  (None, 25, 25, 32)           96        ['conv2d_903[0][0]']
#  atchNormalization)
#
#  batch_normalization_925 (B  (None, 25, 25, 32)           96        ['conv2d_905[0][0]']
#  atchNormalization)
#
#  batch_normalization_928 (B  (None, 25, 25, 64)           192       ['conv2d_908[0][0]']
#  atchNormalization)
#
#  activation_903 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_923[0][0
#  )                                                                  ]']
#
#  activation_905 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_925[0][0
#  )                                                                  ]']
#
#  activation_908 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_928[0][0
#  )                                                                  ]']
#
#  block35_6_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_903[0][0]',
#  te)                                                                 'activation_905[0][0]',
#                                                                      'activation_908[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_45 (Cus  (None, 25, 25, 320)          0         ['block35_5_ac[0][0]',
#  tomScaleLayer)                                                      'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_45[0][0]'
#                                                                     ]
#
#  conv2d_912 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_932 (B  (None, 25, 25, 32)           96        ['conv2d_912[0][0]']
#  atchNormalization)
#
#  activation_912 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_932[0][0
#  )                                                                  ]']
#
#  conv2d_910 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
# ...
#  conv2d_1053 (Conv2D)        (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_1073 (  (None, 5, 5, 192)            576       ['conv2d_1053[0][0]']
#  BatchNormalization)
#
#  activation_1053 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1073[0][
#  n)                                                                 0]']
#
#  conv2d_1054 (Conv2D)        (None, 5, 5, 224)            129024    ['activation_1053[0][0]']
#
#  batch_normalization_1074 (  (None, 5, 5, 224)            672       ['conv2d_1054[0][0]']
#  BatchNormalization)
#
#  activation_1054 (Activatio  (None, 5, 5, 224)            0         ['batch_normalization_1074[0][
#  n)                                                                 0]']
#
#  conv2d_1052 (Conv2D)        (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_1055 (Conv2D)        (None, 5, 5, 256)            172032    ['activation_1054[0][0]']
#
#  batch_normalization_1072 (  (None, 5, 5, 192)            576       ['conv2d_1052[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1075 (  (None, 5, 5, 256)            768       ['conv2d_1055[0][0]']
#  BatchNormalization)
#
#  activation_1052 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1072[0][
#  n)                                                                 0]']
#
#  activation_1055 (Activatio  (None, 5, 5, 256)            0         ['batch_normalization_1075[0][
#  n)                                                                 0]']
#
#  block8_8_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_1052[0][0]',
#  e)                                                                  'activation_1055[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_77 (Cus  (None, 5, 5, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_77[0][0]'
#                                                                     ]
#
#  conv2d_1057 (Conv2D)        (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_1077 (  (None, 5, 5, 192)            576       ['conv2d_1057[0][0]']
#  BatchNormalization)
#
#  activation_1057 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1077[0][
#  n)                                                                 0]']
#
#  conv2d_1058 (Conv2D)        (None, 5, 5, 224)            129024    ['activation_1057[0][0]']
#
#  batch_normalization_1078 (  (None, 5, 5, 224)            672       ['conv2d_1058[0][0]']
#  BatchNormalization)
#
#  activation_1058 (Activatio  (None, 5, 5, 224)            0         ['batch_normalization_1078[0][
#  n)                                                                 0]']
#
#  conv2d_1056 (Conv2D)        (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_1059 (Conv2D)        (None, 5, 5, 256)            172032    ['activation_1058[0][0]']
#
#  batch_normalization_1076 (  (None, 5, 5, 192)            576       ['conv2d_1056[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1079 (  (None, 5, 5, 256)            768       ['conv2d_1059[0][0]']
#  BatchNormalization)
#
#  activation_1056 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1076[0][
#  n)                                                                 0]']
#
#  activation_1059 (Activatio  (None, 5, 5, 256)            0         ['batch_normalization_1079[0][
#  n)                                                                 0]']
#
#  block8_9_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_1056[0][0]',
#  e)                                                                  'activation_1059[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_78 (Cus  (None, 5, 5, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_78[0][0]'
#                                                                     ]
#
#  conv2d_1061 (Conv2D)        (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_1081 (  (None, 5, 5, 192)            576       ['conv2d_1061[0][0]']
#  BatchNormalization)
#
#  activation_1061 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1081[0][
#  n)                                                                 0]']
#
#  conv2d_1062 (Conv2D)        (None, 5, 5, 224)            129024    ['activation_1061[0][0]']
#
#  batch_normalization_1082 (  (None, 5, 5, 224)            672       ['conv2d_1062[0][0]']
#  BatchNormalization)
#
#  activation_1062 (Activatio  (None, 5, 5, 224)            0         ['batch_normalization_1082[0][
#  n)                                                                 0]']
#
#  conv2d_1060 (Conv2D)        (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_1063 (Conv2D)        (None, 5, 5, 256)            172032    ['activation_1062[0][0]']
#
#  batch_normalization_1080 (  (None, 5, 5, 192)            576       ['conv2d_1060[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1083 (  (None, 5, 5, 256)            768       ['conv2d_1063[0][0]']
#  BatchNormalization)
#
#  activation_1060 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1080[0][
#  n)                                                                 0]']
#
#  activation_1063 (Activatio  (None, 5, 5, 256)            0         ['batch_normalization_1083[0][
#  n)                                                                 0]']
#
#  block8_10_mixed (Concatena  (None, 5, 5, 448)            0         ['activation_1060[0][0]',
#  te)                                                                 'activation_1063[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 5, 5, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_79 (Cus  (None, 5, 5, 2080)           0         ['block8_9_ac[0][0]',
#  tomScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 5, 5, 1536)           3194880   ['custom_scale_layer_79[0][0]'
#                                                                     ]
#
#  conv_7b_bn (BatchNormaliza  (None, 5, 5, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 5, 5, 1536)           0         ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  flatten_10 (Flatten)        (None, 1536)                 0         ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  dense_40 (Dense)            (None, 256)                  393472    ['flatten_10[0][0]']
#
#  batch_normalization_1084 (  (None, 256)                  1024      ['dense_40[0][0]']
#  BatchNormalization)
#
#  dropout_10 (Dropout)        (None, 256)                  0         ['batch_normalization_1084[0][
#                                                                     0]']
#
#  dense_41 (Dense)            (None, 128)                  32896     ['dropout_10[0][0]']
#
#  batch_normalization_1085 (  (None, 128)                  512       ['dense_41[0][0]']
#  BatchNormalization)
#
#  dense_42 (Dense)            (None, 64)                   8256      ['batch_normalization_1085[0][
#                                                                     0]']
#
#  dense_43 (Dense)            (None, 7)                    455       ['dense_42[0][0]']
#
# ==================================================================================================
# Total params: 54773351 (208.94 MB)
# Trainable params: 435847 (1.66 MB)
# Non-trainable params: 54337504 (207.28 MB)
# __________________________________________________________________________________________________

# %%
# Compile the model after unfreezing layers for fine-tuning
model.compile(
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),  # Use categorical_crossentropy
    optimizer=RMSprop(learning_rate=base_learning_rate/10),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='accuracy')]  # Use CategoricalAccuracy
)

# Set up callbacks
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=3, factor=0.2, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# Train the model with early stopping and learning rate reduction
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=25,
    validation_data=val_generator,
    validation_steps=len(val_generator) // batch_size,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/25
# 756/756 [==============================] - 233s 276ms/step - loss: 1.2461 - accuracy: 0.5197 - val_loss: 0.9053 - val_accuracy: 0.7396 - lr: 1.0000e-04
# Epoch 2/25
# 756/756 [==============================] - 204s 270ms/step - loss: 0.8147 - accuracy: 0.6901 - val_loss: 0.7068 - val_accuracy: 0.7708 - lr: 1.0000e-04
# Epoch 3/25
# 756/756 [==============================] - 206s 272ms/step - loss: 0.6884 - accuracy: 0.7419 - val_loss: 0.7374 - val_accuracy: 0.7552 - lr: 1.0000e-04
# Epoch 4/25
# 756/756 [==============================] - 205s 271ms/step - loss: 0.5855 - accuracy: 0.7838 - val_loss: 0.5761 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 5/25
# 756/756 [==============================] - 202s 266ms/step - loss: 0.5254 - accuracy: 0.8078 - val_loss: 0.6697 - val_accuracy: 0.7969 - lr: 1.0000e-04
# Epoch 6/25
# 756/756 [==============================] - 202s 267ms/step - loss: 0.4737 - accuracy: 0.8240 - val_loss: 0.5288 - val_accuracy: 0.7917 - lr: 1.0000e-04
# Epoch 7/25
# 756/756 [==============================] - 203s 269ms/step - loss: 0.4136 - accuracy: 0.8482 - val_loss: 0.3803 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Epoch 8/25
# 756/756 [==============================] - 203s 269ms/step - loss: 0.3874 - accuracy: 0.8608 - val_loss: 0.3539 - val_accuracy: 0.8698 - lr: 1.0000e-04
# Epoch 9/25
# 756/756 [==============================] - 204s 269ms/step - loss: 0.3706 - accuracy: 0.8694 - val_loss: 0.6687 - val_accuracy: 0.7708 - lr: 1.0000e-04
# Epoch 10/25
# 756/756 [==============================] - 204s 270ms/step - loss: 0.3235 - accuracy: 0.8826 - val_loss: 0.3064 - val_accuracy: 0.9115 - lr: 1.0000e-04
# Epoch 11/25
# 756/756 [==============================] - 202s 268ms/step - loss: 0.3183 - accuracy: 0.8903 - val_loss: 0.2501 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 12/25
# 756/756 [==============================] - 203s 268ms/step - loss: 0.3031 - accuracy: 0.8953 - val_loss: 0.3657 - val_accuracy: 0.8854 - lr: 1.0000e-04
# Epoch 13/25
# 756/756 [==============================] - 203s 269ms/step - loss: 0.2841 - accuracy: 0.9009 - val_loss: 0.2824 - val_accuracy: 0.9115 - lr: 1.0000e-04
# Epoch 14/25
# 756/756 [==============================] - 202s 268ms/step - loss: 0.2646 - accuracy: 0.9083 - val_loss: 0.2558 - val_accuracy: 0.9271 - lr: 1.0000e-04
# Epoch 15/25
# 756/756 [==============================] - 204s 270ms/step - loss: 0.2515 - accuracy: 0.9120 - val_loss: 0.2398 - val_accuracy: 0.9271 - lr: 1.0000e-04
# Epoch 16/25
# 756/756 [==============================] - 203s 268ms/step - loss: 0.2516 - accuracy: 0.9117 - val_loss: 0.3591 - val_accuracy: 0.8854 - lr: 1.0000e-04
# Epoch 17/25
# 756/756 [==============================] - 204s 270ms/step - loss: 0.2421 - accuracy: 0.9151 - val_loss: 0.2105 - val_accuracy: 0.9375 - lr: 1.0000e-04
# Epoch 18/25
# 756/756 [==============================] - 204s 270ms/step - loss: 0.2111 - accuracy: 0.9281 - val_loss: 0.1903 - val_accuracy: 0.9427 - lr: 1.0000e-04
# Epoch 19/25
# 756/756 [==============================] - 205s 271ms/step - loss: 0.2084 - accuracy: 0.9311 - val_loss: 0.4028 - val_accuracy: 0.8802 - lr: 1.0000e-04
# Epoch 20/25
# 756/756 [==============================] - 205s 271ms/step - loss: 0.2023 - accuracy: 0.9314 - val_loss: 0.2670 - val_accuracy: 0.9219 - lr: 1.0000e-04
# Epoch 21/25
# 756/756 [==============================] - 204s 269ms/step - loss: 0.1875 - accuracy: 0.9336 - val_loss: 0.1873 - val_accuracy: 0.9219 - lr: 1.0000e-04
# Epoch 22/25
# 756/756 [==============================] - 203s 268ms/step - loss: 0.1819 - accuracy: 0.9392 - val_loss: 0.1343 - val_accuracy: 0.9635 - lr: 1.0000e-04
# Epoch 23/25
# 756/756 [==============================] - 202s 268ms/step - loss: 0.1776 - accuracy: 0.9390 - val_loss: 0.0794 - val_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 24/25
# 756/756 [==============================] - 204s 270ms/step - loss: 0.1674 - accuracy: 0.9417 - val_loss: 0.3031 - val_accuracy: 0.9219 - lr: 1.0000e-04
# Epoch 25/25
# 756/756 [==============================] - 204s 269ms/step - loss: 0.1676 - accuracy: 0.9436 - val_loss: 0.1102 - val_accuracy: 0.9740 - lr: 1.0000e-04

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
train_loss, train_accuracy = model.evaluate(train_generator)

print(f'Train accuracy: {train_accuracy:.4f}')
# Out:
# 757/757 [==============================] - 192s 254ms/step - loss: 0.0965 - accuracy: 0.9670
# Train accuracy: 0.9670

# %%
# Evaluate the model on the test data using the test generator
test_loss, test_accuracy = model.evaluate(test_generator)

print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# 131/131 [==============================] - 34s 258ms/step - loss: 0.1554 - accuracy: 0.9482
# Test accuracy: 0.9482

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Make Predictions
y_pred = model.predict(test_generator)

# Convert Predictions and True Labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = test_generator.classes

# Create the Confusion Matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)


# Create a dictionary to map class indices to class names
class_indices = test_generator.class_indices
class_names = {v: k for k, v in class_indices.items()}


# Calculate precision, recall, and F1 score for each class
precision = precision_score(y_true_classes, y_pred_classes, average=None)
recall = recall_score(y_true_classes, y_pred_classes, average=None)
f1 = f1_score(y_true_classes, y_pred_classes, average=None)

# Visualize the Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices,
            yticklabels=test_generator.class_indices)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()


# Create a list of class names
class_names_list = [class_names[i] for i in range(len(class_indices))]

# Create a DataFrame to organize the results
results_df = pd.DataFrame({
    'Class': class_names_list,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1
})

# Print the results table
print(results_df)
# Out:
# 131/131 [==============================] - 36s 251ms/step
#                               Class  Precision    Recall  F1 Score
# 0    carcinoma_in_situ_filtered_nlm   0.883792  0.969799  0.924800
# 1     light_dysplastic_filtered_nlm   0.951389  0.919463  0.935154
# 2  moderate_dysplastic_filtered_nlm   0.959259  0.872054  0.913580
# 3      normal_columnar_filtered_nlm   0.969388  0.956376  0.962838
# 4  normal_intermediate_filtered_nlm   0.996656  1.000000  0.998325
# 5   normal_superficiel_filtered_nlm   0.996633  0.996633  0.996633
# 6    severe_dysplastic_filtered_nlm   0.889610  0.922559  0.905785

# %%
# Save the model with custom layers and weights
model.save('InceptionResNetV2.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# from keras.applications import ResNet50V2

# Load the model
new_model = tf.keras.models.load_model('/content/drive/MyDrive/InceptionResNetV2.h5')

# Compile the model after unfreezing layers for fine-tuning
# new_model.compile(
#     loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),  # Use categorical_crossentropy
#     optimizer=RMSprop(learning_rate=base_learning_rate/10),
#     metrics=[tf.keras.metrics.CategoricalAccuracy(name='accuracy')]  # Use CategoricalAccuracy
# )

# # Set up callbacks
# reduce_lr = ReduceLROnPlateau(monitor='loss', patience=3, factor=0.2, min_lr=1e-6)
# early_stopping = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# # Train the new_model with early stopping and learning rate reduction
# history = new_model.fit(
#     train_generator,
#     steps_per_epoch=train_generator.samples // batch_size,
#     epochs=50,
#     initial_epoch=25,
#     validation_data=val_generator,
#     validation_steps=len(val_generator) // batch_size,
#     callbacks=[reduce_lr, early_stopping]
# )

# %%
train_loss, train_accuracy = new_model.evaluate(train_generator)

print(f'Train accuracy: {train_accuracy:.4f}')
# Out:
# 757/757 [==============================] - 221s 275ms/step - loss: 0.0989 - accuracy: 0.9670
# Train accuracy: 0.9670

# %%
# Evaluate the model on the test data using the test generator
test_loss, test_accuracy = new_model.evaluate(test_generator)

print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# 131/131 [==============================] - 36s 271ms/step - loss: 0.1474 - accuracy: 0.9482
# Test accuracy: 0.9482

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Make Predictions
y_pred = new_model.predict(test_generator)

# Convert Predictions and True Labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = test_generator.classes

# Create the Confusion Matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)


# Create a dictionary to map class indices to class names
class_indices = test_generator.class_indices
class_names = {v: k for k, v in class_indices.items()}


# Calculate precision, recall, and F1 score for each class
precision = precision_score(y_true_classes, y_pred_classes, average=None)
recall = recall_score(y_true_classes, y_pred_classes, average=None)
f1 = f1_score(y_true_classes, y_pred_classes, average=None)

# Visualize the Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices,
            yticklabels=test_generator.class_indices)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()


# Create a list of class names
class_names_list = [class_names[i] for i in range(len(class_indices))]

# Create a DataFrame to organize the results
results_df = pd.DataFrame({
    'Class': class_names_list,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1
})

# Print the results table
print(results_df)
# Out:
# 131/131 [==============================] - 36s 250ms/step
#                               Class  Precision    Recall  F1 Score
# 0    carcinoma_in_situ_filtered_nlm   0.871951  0.959732  0.913738
# 1     light_dysplastic_filtered_nlm   0.928571  0.916107  0.922297
# 2  moderate_dysplastic_filtered_nlm   0.973485  0.865320  0.916221
# 3      normal_columnar_filtered_nlm   0.966887  0.979866  0.973333
# 4  normal_intermediate_filtered_nlm   0.993311  0.996644  0.994975
# 5   normal_superficiel_filtered_nlm   0.996633  0.996633  0.996633
# 6    severe_dysplastic_filtered_nlm   0.872910  0.878788  0.875839

# %%
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Define the determine_cancerous function
def determine_cancerous(class_name):
    cancerous_classes = {
        'carcinoma_in_situ_filtered_nlm': True,
        'light_dysplastic_filtered_nlm': True,
        'moderate_dysplastic_filtered_nlm': True,
        'normal_columnar_filtered_nlm': False,
        'normal_intermediate_filtered_nlm':False,
        'normal_superficiel_filtered_nlm': False,
        'severe_dysplastic_filtered_nlm': True,
    }

    return cancerous_classes.get(class_name, None)

# Load and preprocess a sample image
image_path = '/content/cervix-cancer-Deep-learning/Herlev Dataset resized/test/normal_superficiel/157183412-157183638-001 - Copy (2).BMP'
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.  # rescale

# Make a prediction
prediction = new_model.predict(img_array)

# Convert the prediction to class name
class_index = np.argmax(prediction)
class_name = list(test_generator.class_indices.keys())[class_index]

plt.imshow(img)
plt.show()

# Print the predicted class name
print(f'Predicted Class: {class_name}')

# Determine if it's cancerous or not
is_cancerous = determine_cancerous(class_name)



# Print whether it's cancerous or not
if is_cancerous is not None:
    if is_cancerous:
        print('Cancerous')
    else:
        print('Non-cancerous')
else:
    print('Class not found in dictionary')

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Define the NLM filter function
def nlm_filter(image):
    filtered_image = cv2.fastNlMeansDenoisingColored(image, None, 10, 10, 7, 21)  # Adjust parameters as needed
    return filtered_image


# Define the determine_cancerous function
def determine_cancerous(class_name):
    cancerous_classes = {
        'carcinoma_in_situ_filtered_nlm': True,
        'light_dysplastic_filtered_nlm': True,
        'moderate_dysplastic_filtered_nlm': True,
        'normal_columnar_filtered_nlm': False,
        'normal_intermediate_filtered_nlm': False,
        'normal_superficiel_filtered_nlm': False,
        'severe_dysplastic_filtered_nlm': True,
    }
    return cancerous_classes.get(class_name, None)

# Load and preprocess a sample image
image_path = '/content/cervix-cancer-Deep-learning/Herlev Dataset resized/test/normal_superficiel/157222737-157222750-002 - Copy (2).BMP'  # Replace with the actual path to your image
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB


filtered_image = nlm_filter(img_rgb)

# Display the filtered image
plt.imshow(filtered_image)
# plt.title('Filtered Image')
plt.show()

# Rescale and expand dimensions
img_array = np.expand_dims(filtered_image / 255., axis=0)

# Make a prediction
prediction = new_model.predict(img_array)

# Convert the prediction to class name
class_index = np.argmax(prediction)
class_name = list(test_generator.class_indices.keys())[class_index]

# Print the predicted class name
print(f'Predicted Class: {class_name}')

# Determine if it's cancerous or not
is_cancerous = determine_cancerous(class_name)

# Print whether it's cancerous or not
if is_cancerous is not None:
    if is_cancerous:
        print('Cancerous')
    else:
        print('Non-cancerous')
else:
    print('Class not found in dictionary')
