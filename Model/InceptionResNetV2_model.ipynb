# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Aditya1Jhaveri/cervix-cancer-Deep-learning.git
# Out:
# Cloning into 'cervix-cancer-Deep-learning'...
# remote: Enumerating objects: 53295, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 53295 (delta 20), reused 43 (delta 7), pack-reused 53234
# Receiving objects: 100% (53295/53295), 1.75 GiB | 35.75 MiB/s, done.
# Resolving deltas: 100% (226/226), done.
# Updating files: 100% (50901/50901), done.

# %%
import tensorflow as tf
from keras.applications import InceptionResNetV2
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization,Flatten
from keras.models import Model
from keras.optimizers import RMSprop
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn import preprocessing
from keras.utils import to_categorical



# Set your data directories and parameters
train_data_dir = '/content/cervix-cancer-Deep-learning/NEW_DATASET/train'
test_data_dir = '/content/cervix-cancer-Deep-learning/NEW_DATASET/test'
val_data_dir = '/content/cervix-cancer-Deep-learning/NEW_DATASET/validation'


img_width, img_height = 224, 224
batch_size = 16
base_learning_rate = 0.001  # Adjust as needed

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2,
    fill_mode='nearest'
)

# Data preprocessing for test
test_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2,
    fill_mode='nearest'
)

# Load the data using data generators
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',  # Automatically one-hot encodes labels
    shuffle=True  # Shuffle the data
)
print(f"Found {train_generator.samples} images belonging to {len(train_generator.class_indices)} classes in train dataset.")

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',  # Automatically one-hot encodes labels
    shuffle=False  # No need to shuffle test data
)
print(f"Found {test_generator.samples} images belonging to {len(test_generator.class_indices)} classes in test dataset.")

val_generator = val_datagen.flow_from_directory(
    val_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',  # Automatically one-hot encodes labels
    shuffle=False  # No need to shuffle test data
)
print(f"Found {val_generator.samples} images belonging to {len(val_generator.class_indices)} classes in validation dataset.")
# Out:
# Found 12110 images belonging to 7 classes.
# Found 12110 images belonging to 7 classes in train dataset.
# Found 2083 images belonging to 7 classes.
# Found 2083 images belonging to 7 classes in test dataset.
# Found 3111 images belonging to 7 classes.
# Found 3111 images belonging to 7 classes in validation dataset.

# %%
# Load the InceptionResNetV2 model
base_model = InceptionResNetV2(include_top=False, weights='imagenet', input_shape=(224, 224, 3))


# Add your custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)
# x = Dropout(0.5)(x)
x = Flatten()(x)

x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
# x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
# x = BatchNormalization()(x)

predictions = Dense(train_generator.num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)


base_model.trainable = True

set_trainable = False

for layer in base_model.layers:
  if layer.name == 'block8_2_conv':
    set_trainable = True
  if set_trainable:
    layer.trainable = True
  else:
    layer.trainable = False

for layer in base_model.layers:
  print(layer.name,layer.trainable)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 2s 0us/step
# input_1 False
# conv2d False
# batch_normalization False
# activation False
# conv2d_1 False
# batch_normalization_1 False
# activation_1 False
# conv2d_2 False
# batch_normalization_2 False
# activation_2 False
# max_pooling2d False
# conv2d_3 False
# batch_normalization_3 False
# activation_3 False
# conv2d_4 False
# batch_normalization_4 False
# activation_4 False
# max_pooling2d_1 False
# conv2d_8 False
# batch_normalization_8 False
# activation_8 False
# conv2d_6 False
# conv2d_9 False
# batch_normalization_6 False
# batch_normalization_9 False
# activation_6 False
# activation_9 False
# average_pooling2d False
# conv2d_5 False
# conv2d_7 False
# conv2d_10 False
# conv2d_11 False
# batch_normalization_5 False
# batch_normalization_7 False
# batch_normalization_10 False
# batch_normalization_11 False
# activation_5 False
# activation_7 False
# activation_10 False
# activation_11 False
# mixed_5b False
# conv2d_15 False
# batch_normalization_15 False
# activation_15 False
# conv2d_13 False
# conv2d_16 False
# batch_normalization_13 False
# batch_normalization_16 False
# activation_13 False
# activation_16 False
# conv2d_12 False
# conv2d_14 False
# conv2d_17 False
# batch_normalization_12 False
# batch_normalization_14 False
# batch_normalization_17 False
# activation_12 False
# activation_14 False
# activation_17 False
# block35_1_mixed False
# block35_1_conv False
# custom_scale_layer False
# block35_1_ac False
# conv2d_21 False
# batch_normalization_21 False
# activation_21 False
# conv2d_19 False
# conv2d_22 False
# batch_normalization_19 False
# batch_normalization_22 False
# activation_19 False
# activation_22 False
# conv2d_18 False
# conv2d_20 False
# conv2d_23 False
# batch_normalization_18 False
# batch_normalization_20 False
# batch_normalization_23 False
# activation_18 False
# activation_20 False
# activation_23 False
# block35_2_mixed False
# block35_2_conv False
# custom_scale_layer_1 False
# block35_2_ac False
# conv2d_27 False
# batch_normalization_27 False
# activation_27 False
# conv2d_25 False
# conv2d_28 False
# batch_normalization_25 False
# batch_normalization_28 False
# activation_25 False
# activation_28 False
# conv2d_24 False
# conv2d_26 False
# conv2d_29 False
# batch_normalization_24 False
# batch_normalization_26 False
# batch_normalization_29 False
# activation_24 False
# activation_26 False
# activation_29 False
# block35_3_mixed False
# block35_3_conv False
# custom_scale_layer_2 False
# block35_3_ac False
# conv2d_33 False
# batch_normalization_33 False
# activation_33 False
# conv2d_31 False
# conv2d_34 False
# batch_normalization_31 False
# batch_normalization_34 False
# activation_31 False
# activation_34 False
# conv2d_30 False
# conv2d_32 False
# conv2d_35 False
# batch_normalization_30 False
# batch_normalization_32 False
# batch_normalization_35 False
# activation_30 False
# activation_32 False
# activation_35 False
# block35_4_mixed False
# block35_4_conv False
# custom_scale_layer_3 False
# block35_4_ac False
# conv2d_39 False
# batch_normalization_39 False
# activation_39 False
# conv2d_37 False
# conv2d_40 False
# batch_normalization_37 False
# batch_normalization_40 False
# activation_37 False
# activation_40 False
# conv2d_36 False
# conv2d_38 False
# conv2d_41 False
# batch_normalization_36 False
# batch_normalization_38 False
# batch_normalization_41 False
# activation_36 False
# activation_38 False
# activation_41 False
# block35_5_mixed False
# block35_5_conv False
# custom_scale_layer_4 False
# block35_5_ac False
# conv2d_45 False
# batch_normalization_45 False
# activation_45 False
# conv2d_43 False
# conv2d_46 False
# batch_normalization_43 False
# batch_normalization_46 False
# activation_43 False
# activation_46 False
# conv2d_42 False
# conv2d_44 False
# conv2d_47 False
# batch_normalization_42 False
# batch_normalization_44 False
# batch_normalization_47 False
# activation_42 False
# activation_44 False
# activation_47 False
# block35_6_mixed False
# block35_6_conv False
# custom_scale_layer_5 False
# block35_6_ac False
# conv2d_51 False
# batch_normalization_51 False
# activation_51 False
# conv2d_49 False
# conv2d_52 False
# batch_normalization_49 False
# batch_normalization_52 False
# activation_49 False
# activation_52 False
# conv2d_48 False
# conv2d_50 False
# conv2d_53 False
# batch_normalization_48 False
# batch_normalization_50 False
# batch_normalization_53 False
# activation_48 False
# activation_50 False
# activation_53 False
# block35_7_mixed False
# block35_7_conv False
# custom_scale_layer_6 False
# block35_7_ac False
# conv2d_57 False
# batch_normalization_57 False
# activation_57 False
# conv2d_55 False
# conv2d_58 False
# batch_normalization_55 False
# batch_normalization_58 False
# activation_55 False
# activation_58 False
# conv2d_54 False
# conv2d_56 False
# conv2d_59 False
# batch_normalization_54 False
# batch_normalization_56 False
# batch_normalization_59 False
# activation_54 False
# activation_56 False
# activation_59 False
# block35_8_mixed False
# block35_8_conv False
# custom_scale_layer_7 False
# block35_8_ac False
# conv2d_63 False
# batch_normalization_63 False
# activation_63 False
# conv2d_61 False
# conv2d_64 False
# batch_normalization_61 False
# batch_normalization_64 False
# activation_61 False
# activation_64 False
# conv2d_60 False
# conv2d_62 False
# conv2d_65 False
# batch_normalization_60 False
# batch_normalization_62 False
# batch_normalization_65 False
# activation_60 False
# activation_62 False
# activation_65 False
# block35_9_mixed False
# block35_9_conv False
# custom_scale_layer_8 False
# block35_9_ac False
# conv2d_69 False
# batch_normalization_69 False
# activation_69 False
# conv2d_67 False
# conv2d_70 False
# batch_normalization_67 False
# batch_normalization_70 False
# activation_67 False
# activation_70 False
# conv2d_66 False
# conv2d_68 False
# conv2d_71 False
# batch_normalization_66 False
# batch_normalization_68 False
# batch_normalization_71 False
# activation_66 False
# activation_68 False
# activation_71 False
# block35_10_mixed False
# block35_10_conv False
# custom_scale_layer_9 False
# block35_10_ac False
# conv2d_73 False
# batch_normalization_73 False
# activation_73 False
# conv2d_74 False
# batch_normalization_74 False
# activation_74 False
# conv2d_72 False
# conv2d_75 False
# batch_normalization_72 False
# batch_normalization_75 False
# activation_72 False
# activation_75 False
# max_pooling2d_2 False
# mixed_6a False
# conv2d_77 False
# batch_normalization_77 False
# activation_77 False
# conv2d_78 False
# batch_normalization_78 False
# activation_78 False
# conv2d_76 False
# conv2d_79 False
# batch_normalization_76 False
# batch_normalization_79 False
# activation_76 False
# activation_79 False
# block17_1_mixed False
# block17_1_conv False
# custom_scale_layer_10 False
# block17_1_ac False
# conv2d_81 False
# batch_normalization_81 False
# activation_81 False
# conv2d_82 False
# batch_normalization_82 False
# activation_82 False
# conv2d_80 False
# conv2d_83 False
# batch_normalization_80 False
# batch_normalization_83 False
# activation_80 False
# activation_83 False
# block17_2_mixed False
# block17_2_conv False
# custom_scale_layer_11 False
# block17_2_ac False
# conv2d_85 False
# batch_normalization_85 False
# activation_85 False
# conv2d_86 False
# batch_normalization_86 False
# activation_86 False
# conv2d_84 False
# conv2d_87 False
# batch_normalization_84 False
# batch_normalization_87 False
# activation_84 False
# activation_87 False
# block17_3_mixed False
# block17_3_conv False
# custom_scale_layer_12 False
# block17_3_ac False
# conv2d_89 False
# batch_normalization_89 False
# activation_89 False
# conv2d_90 False
# batch_normalization_90 False
# activation_90 False
# conv2d_88 False
# conv2d_91 False
# batch_normalization_88 False
# batch_normalization_91 False
# activation_88 False
# activation_91 False
# block17_4_mixed False
# block17_4_conv False
# custom_scale_layer_13 False
# block17_4_ac False
# conv2d_93 False
# batch_normalization_93 False
# activation_93 False
# conv2d_94 False
# batch_normalization_94 False
# activation_94 False
# conv2d_92 False
# conv2d_95 False
# batch_normalization_92 False
# batch_normalization_95 False
# activation_92 False
# activation_95 False
# block17_5_mixed False
# block17_5_conv False
# custom_scale_layer_14 False
# block17_5_ac False
# conv2d_97 False
# batch_normalization_97 False
# activation_97 False
# conv2d_98 False
# batch_normalization_98 False
# activation_98 False
# conv2d_96 False
# conv2d_99 False
# batch_normalization_96 False
# batch_normalization_99 False
# activation_96 False
# activation_99 False
# block17_6_mixed False
# block17_6_conv False
# custom_scale_layer_15 False
# block17_6_ac False
# conv2d_101 False
# batch_normalization_101 False
# activation_101 False
# conv2d_102 False
# batch_normalization_102 False
# activation_102 False
# conv2d_100 False
# conv2d_103 False
# batch_normalization_100 False
# batch_normalization_103 False
# activation_100 False
# activation_103 False
# block17_7_mixed False
# block17_7_conv False
# custom_scale_layer_16 False
# block17_7_ac False
# conv2d_105 False
# batch_normalization_105 False
# activation_105 False
# conv2d_106 False
# batch_normalization_106 False
# activation_106 False
# conv2d_104 False
# conv2d_107 False
# batch_normalization_104 False
# batch_normalization_107 False
# activation_104 False
# activation_107 False
# block17_8_mixed False
# block17_8_conv False
# custom_scale_layer_17 False
# block17_8_ac False
# conv2d_109 False
# batch_normalization_109 False
# activation_109 False
# conv2d_110 False
# batch_normalization_110 False
# activation_110 False
# conv2d_108 False
# conv2d_111 False
# batch_normalization_108 False
# batch_normalization_111 False
# activation_108 False
# activation_111 False
# block17_9_mixed False
# block17_9_conv False
# custom_scale_layer_18 False
# block17_9_ac False
# conv2d_113 False
# batch_normalization_113 False
# activation_113 False
# conv2d_114 False
# batch_normalization_114 False
# activation_114 False
# conv2d_112 False
# conv2d_115 False
# batch_normalization_112 False
# batch_normalization_115 False
# activation_112 False
# activation_115 False
# block17_10_mixed False
# block17_10_conv False
# custom_scale_layer_19 False
# block17_10_ac False
# conv2d_117 False
# batch_normalization_117 False
# activation_117 False
# conv2d_118 False
# batch_normalization_118 False
# activation_118 False
# conv2d_116 False
# conv2d_119 False
# batch_normalization_116 False
# batch_normalization_119 False
# activation_116 False
# activation_119 False
# block17_11_mixed False
# block17_11_conv False
# custom_scale_layer_20 False
# block17_11_ac False
# conv2d_121 False
# batch_normalization_121 False
# activation_121 False
# conv2d_122 False
# batch_normalization_122 False
# activation_122 False
# conv2d_120 False
# conv2d_123 False
# batch_normalization_120 False
# batch_normalization_123 False
# activation_120 False
# activation_123 False
# block17_12_mixed False
# block17_12_conv False
# custom_scale_layer_21 False
# block17_12_ac False
# conv2d_125 False
# batch_normalization_125 False
# activation_125 False
# conv2d_126 False
# batch_normalization_126 False
# activation_126 False
# conv2d_124 False
# conv2d_127 False
# batch_normalization_124 False
# batch_normalization_127 False
# activation_124 False
# activation_127 False
# block17_13_mixed False
# block17_13_conv False
# custom_scale_layer_22 False
# block17_13_ac False
# conv2d_129 False
# batch_normalization_129 False
# activation_129 False
# conv2d_130 False
# batch_normalization_130 False
# activation_130 False
# conv2d_128 False
# conv2d_131 False
# batch_normalization_128 False
# batch_normalization_131 False
# activation_128 False
# activation_131 False
# block17_14_mixed False
# block17_14_conv False
# custom_scale_layer_23 False
# block17_14_ac False
# conv2d_133 False
# batch_normalization_133 False
# activation_133 False
# conv2d_134 False
# batch_normalization_134 False
# activation_134 False
# conv2d_132 False
# conv2d_135 False
# batch_normalization_132 False
# batch_normalization_135 False
# activation_132 False
# activation_135 False
# block17_15_mixed False
# block17_15_conv False
# custom_scale_layer_24 False
# block17_15_ac False
# conv2d_137 False
# batch_normalization_137 False
# activation_137 False
# conv2d_138 False
# batch_normalization_138 False
# activation_138 False
# conv2d_136 False
# conv2d_139 False
# batch_normalization_136 False
# batch_normalization_139 False
# activation_136 False
# activation_139 False
# block17_16_mixed False
# block17_16_conv False
# custom_scale_layer_25 False
# block17_16_ac False
# conv2d_141 False
# batch_normalization_141 False
# activation_141 False
# conv2d_142 False
# batch_normalization_142 False
# activation_142 False
# conv2d_140 False
# conv2d_143 False
# batch_normalization_140 False
# batch_normalization_143 False
# activation_140 False
# activation_143 False
# block17_17_mixed False
# block17_17_conv False
# custom_scale_layer_26 False
# block17_17_ac False
# conv2d_145 False
# batch_normalization_145 False
# activation_145 False
# conv2d_146 False
# batch_normalization_146 False
# activation_146 False
# conv2d_144 False
# conv2d_147 False
# batch_normalization_144 False
# batch_normalization_147 False
# activation_144 False
# activation_147 False
# block17_18_mixed False
# block17_18_conv False
# custom_scale_layer_27 False
# block17_18_ac False
# conv2d_149 False
# batch_normalization_149 False
# activation_149 False
# conv2d_150 False
# batch_normalization_150 False
# activation_150 False
# conv2d_148 False
# conv2d_151 False
# batch_normalization_148 False
# batch_normalization_151 False
# activation_148 False
# activation_151 False
# block17_19_mixed False
# block17_19_conv False
# custom_scale_layer_28 False
# block17_19_ac False
# conv2d_153 False
# batch_normalization_153 False
# activation_153 False
# conv2d_154 False
# batch_normalization_154 False
# activation_154 False
# conv2d_152 False
# conv2d_155 False
# batch_normalization_152 False
# batch_normalization_155 False
# activation_152 False
# activation_155 False
# block17_20_mixed False
# block17_20_conv False
# custom_scale_layer_29 False
# block17_20_ac False
# conv2d_160 False
# batch_normalization_160 False
# activation_160 False
# conv2d_156 False
# conv2d_158 False
# conv2d_161 False
# batch_normalization_156 False
# batch_normalization_158 False
# batch_normalization_161 False
# activation_156 False
# activation_158 False
# activation_161 False
# conv2d_157 False
# conv2d_159 False
# conv2d_162 False
# batch_normalization_157 False
# batch_normalization_159 False
# batch_normalization_162 False
# activation_157 False
# activation_159 False
# activation_162 False
# max_pooling2d_3 False
# mixed_7a False
# conv2d_164 False
# batch_normalization_164 False
# activation_164 False
# conv2d_165 False
# batch_normalization_165 False
# activation_165 False
# conv2d_163 False
# conv2d_166 False
# batch_normalization_163 False
# batch_normalization_166 False
# activation_163 False
# activation_166 False
# block8_1_mixed False
# block8_1_conv False
# custom_scale_layer_30 False
# block8_1_ac False
# conv2d_168 False
# batch_normalization_168 False
# activation_168 False
# conv2d_169 False
# batch_normalization_169 False
# activation_169 False
# conv2d_167 False
# conv2d_170 False
# batch_normalization_167 False
# batch_normalization_170 False
# activation_167 False
# activation_170 False
# block8_2_mixed False
# block8_2_conv True
# custom_scale_layer_31 True
# block8_2_ac True
# conv2d_172 True
# batch_normalization_172 True
# activation_172 True
# conv2d_173 True
# batch_normalization_173 True
# activation_173 True
# conv2d_171 True
# conv2d_174 True
# batch_normalization_171 True
# batch_normalization_174 True
# activation_171 True
# activation_174 True
# block8_3_mixed True
# block8_3_conv True
# custom_scale_layer_32 True
# block8_3_ac True
# conv2d_176 True
# batch_normalization_176 True
# activation_176 True
# conv2d_177 True
# batch_normalization_177 True
# activation_177 True
# conv2d_175 True
# conv2d_178 True
# batch_normalization_175 True
# batch_normalization_178 True
# activation_175 True
# activation_178 True
# block8_4_mixed True
# block8_4_conv True
# custom_scale_layer_33 True
# block8_4_ac True
# conv2d_180 True
# batch_normalization_180 True
# activation_180 True
# conv2d_181 True
# batch_normalization_181 True
# activation_181 True
# conv2d_179 True
# conv2d_182 True
# batch_normalization_179 True
# batch_normalization_182 True
# activation_179 True
# activation_182 True
# block8_5_mixed True
# block8_5_conv True
# custom_scale_layer_34 True
# block8_5_ac True
# conv2d_184 True
# batch_normalization_184 True
# activation_184 True
# conv2d_185 True
# batch_normalization_185 True
# activation_185 True
# conv2d_183 True
# conv2d_186 True
# batch_normalization_183 True
# batch_normalization_186 True
# activation_183 True
# activation_186 True
# block8_6_mixed True
# block8_6_conv True
# custom_scale_layer_35 True
# block8_6_ac True
# conv2d_188 True
# batch_normalization_188 True
# activation_188 True
# conv2d_189 True
# batch_normalization_189 True
# activation_189 True
# conv2d_187 True
# conv2d_190 True
# batch_normalization_187 True
# batch_normalization_190 True
# activation_187 True
# activation_190 True
# block8_7_mixed True
# block8_7_conv True
# custom_scale_layer_36 True
# block8_7_ac True
# conv2d_192 True
# batch_normalization_192 True
# activation_192 True
# conv2d_193 True
# batch_normalization_193 True
# activation_193 True
# conv2d_191 True
# conv2d_194 True
# batch_normalization_191 True
# batch_normalization_194 True
# activation_191 True
# activation_194 True
# block8_8_mixed True
# block8_8_conv True
# custom_scale_layer_37 True
# block8_8_ac True
# conv2d_196 True
# batch_normalization_196 True
# activation_196 True
# conv2d_197 True
# batch_normalization_197 True
# activation_197 True
# conv2d_195 True
# conv2d_198 True
# batch_normalization_195 True
# batch_normalization_198 True
# activation_195 True
# activation_198 True
# block8_9_mixed True
# block8_9_conv True
# custom_scale_layer_38 True
# block8_9_ac True
# conv2d_200 True
# batch_normalization_200 True
# activation_200 True
# conv2d_201 True
# batch_normalization_201 True
# activation_201 True
# conv2d_199 True
# conv2d_202 True
# batch_normalization_199 True
# batch_normalization_202 True
# activation_199 True
# activation_202 True
# block8_10_mixed True
# block8_10_conv True
# custom_scale_layer_39 True
# conv_7b True
# conv_7b_bn True
# conv_7b_ac True

# %%
model.summary();
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 111, 111, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 111, 111, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 111, 111, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 109, 109, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 109, 109, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 109, 109, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 109, 109, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 109, 109, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 54, 54, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 54, 54, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 54, 54, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 54, 54, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 52, 52, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 52, 52, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 52, 52, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 25, 25, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 25, 25, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 25, 25, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 25, 25, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 25, 25, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 25, 25, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 25, 25, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 25, 25, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 25, 25, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 25, 25, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 25, 25, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 25, 25, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 25, 25, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 25, 25, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 25, 25, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 25, 25, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 25, 25, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 25, 25, 96)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 25, 25, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 25, 25, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 25, 25, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 25, 25, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 25, 25, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 25, 25, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 25, 25, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 25, 25, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 25, 25, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 25, 25, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 25, 25, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 25, 25, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 25, 25, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 25, 25, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 25, 25, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 25, 25, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 25, 25, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 25, 25, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 25, 25, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 25, 25, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 25, 25, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 25, 25, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 25, 25, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 25, 25, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 25, 25, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 25, 25, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 25, 25, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 25, 25, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 25, 25, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 25, 25, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 25, 25, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 25, 25, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 25, 25, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 25, 25, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 25, 25, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 25, 25, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 25, 25, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 25, 25, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 25, 25, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 25, 25, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 25, 25, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 25, 25, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 25, 25, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 25, 25, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (Ba  (None, 25, 25, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_49 (Ba  (None, 25, 25, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 25, 25, 48)           144       ['conv2d_52[0][0]']
# ...
#  conv2d_192 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (B  (None, 5, 5, 192)            576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_192[0][0]']
#
#  batch_normalization_193 (B  (None, 5, 5, 224)            672       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv2d_191 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_193[0][0]']
#
#  batch_normalization_191 (B  (None, 5, 5, 192)            576       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_194 (B  (None, 5, 5, 256)            768       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (Cus  (None, 5, 5, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_37[0][0]'
#                                                                     ]
#
#  conv2d_196 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 5, 5, 192)            576       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_196[0][0]']
#
#  batch_normalization_197 (B  (None, 5, 5, 224)            672       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_197[0][0]']
#
#  batch_normalization_195 (B  (None, 5, 5, 192)            576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 5, 5, 256)            768       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (Cus  (None, 5, 5, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_38[0][0]'
#                                                                     ]
#
#  conv2d_200 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (B  (None, 5, 5, 192)            576       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_200[0][0]']
#
#  batch_normalization_201 (B  (None, 5, 5, 224)            672       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv2d_199 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_201[0][0]']
#
#  batch_normalization_199 (B  (None, 5, 5, 192)            576       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 5, 5, 256)            768       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 5, 5, 448)            0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 5, 5, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_39 (Cus  (None, 5, 5, 2080)           0         ['block8_9_ac[0][0]',
#  tomScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 5, 5, 1536)           3194880   ['custom_scale_layer_39[0][0]'
#                                                                     ]
#
#  conv_7b_bn (BatchNormaliza  (None, 5, 5, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 5, 5, 1536)           0         ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1536)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 256)                  393472    ['flatten[0][0]']
#
#  batch_normalization_203 (B  (None, 256)                  1024      ['dense[0][0]']
#  atchNormalization)
#
#  dropout (Dropout)           (None, 256)                  0         ['batch_normalization_203[0][0
#                                                                     ]']
#
#  dense_1 (Dense)             (None, 128)                  32896     ['dropout[0][0]']
#
#  batch_normalization_204 (B  (None, 128)                  512       ['dense_1[0][0]']
#  atchNormalization)
#
#  dense_2 (Dense)             (None, 64)                   8256      ['batch_normalization_204[0][0
#                                                                     ]']
#
#  dense_3 (Dense)             (None, 7)                    455       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 54773351 (208.94 MB)
# Trainable params: 20842663 (79.51 MB)
# Non-trainable params: 33930688 (129.44 MB)
# __________________________________________________________________________________________________

# %%
# Compile the model after unfreezing layers for fine-tuning
model.compile(
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),  # Use categorical_crossentropy
    optimizer=RMSprop(learning_rate=base_learning_rate/10),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='accuracy')]  # Use CategoricalAccuracy
)

# Set up callbacks
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=3, factor=0.2, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# Train the model with early stopping and learning rate reduction
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=25,
    validation_data=val_generator,
    validation_steps=len(val_generator) // batch_size,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/25
# 756/756 [==============================] - 298s 343ms/step - loss: 1.2496 - accuracy: 0.5030 - val_loss: 1.0062 - val_accuracy: 0.6719 - lr: 1.0000e-04
# Epoch 2/25
# 756/756 [==============================] - 254s 336ms/step - loss: 0.8471 - accuracy: 0.6698 - val_loss: 1.1175 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 3/25
# 756/756 [==============================] - 255s 337ms/step - loss: 0.7112 - accuracy: 0.7289 - val_loss: 0.6113 - val_accuracy: 0.7865 - lr: 1.0000e-04
# Epoch 4/25
# 756/756 [==============================] - 257s 339ms/step - loss: 0.6058 - accuracy: 0.7730 - val_loss: 0.5049 - val_accuracy: 0.8385 - lr: 1.0000e-04
# Epoch 5/25
# 756/756 [==============================] - 257s 340ms/step - loss: 0.5367 - accuracy: 0.8034 - val_loss: 0.6411 - val_accuracy: 0.7865 - lr: 1.0000e-04
# Epoch 6/25
# 756/756 [==============================] - 251s 331ms/step - loss: 0.4857 - accuracy: 0.8210 - val_loss: 0.7492 - val_accuracy: 0.7865 - lr: 1.0000e-04
# Epoch 7/25
# 756/756 [==============================] - 257s 340ms/step - loss: 0.4283 - accuracy: 0.8426 - val_loss: 0.4585 - val_accuracy: 0.8646 - lr: 1.0000e-04
# Epoch 8/25
# 756/756 [==============================] - 255s 337ms/step - loss: 0.3997 - accuracy: 0.8596 - val_loss: 0.6395 - val_accuracy: 0.8073 - lr: 1.0000e-04
# Epoch 9/25
# 756/756 [==============================] - 260s 344ms/step - loss: 0.3747 - accuracy: 0.8637 - val_loss: 0.4162 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 10/25
# 756/756 [==============================] - 253s 335ms/step - loss: 0.3292 - accuracy: 0.8828 - val_loss: 0.1946 - val_accuracy: 0.9479 - lr: 1.0000e-04
# Epoch 11/25
# 756/756 [==============================] - 254s 336ms/step - loss: 0.3151 - accuracy: 0.8873 - val_loss: 0.3445 - val_accuracy: 0.8698 - lr: 1.0000e-04
# Epoch 12/25
# 756/756 [==============================] - 250s 331ms/step - loss: 0.2919 - accuracy: 0.8973 - val_loss: 0.2223 - val_accuracy: 0.9271 - lr: 1.0000e-04
# Epoch 13/25
# 756/756 [==============================] - 262s 347ms/step - loss: 0.2871 - accuracy: 0.9012 - val_loss: 0.3990 - val_accuracy: 0.8698 - lr: 1.0000e-04
# Epoch 14/25
# 756/756 [==============================] - 248s 328ms/step - loss: 0.2617 - accuracy: 0.9112 - val_loss: 0.3662 - val_accuracy: 0.8542 - lr: 1.0000e-04
# Epoch 15/25
# 756/756 [==============================] - 252s 334ms/step - loss: 0.2470 - accuracy: 0.9141 - val_loss: 0.4115 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 16/25
# 756/756 [==============================] - 252s 333ms/step - loss: 0.2415 - accuracy: 0.9158 - val_loss: 0.2877 - val_accuracy: 0.9115 - lr: 1.0000e-04
# Epoch 17/25
# 756/756 [==============================] - 253s 335ms/step - loss: 0.2237 - accuracy: 0.9218 - val_loss: 0.1253 - val_accuracy: 0.9635 - lr: 1.0000e-04
# Epoch 18/25
# 756/756 [==============================] - 252s 333ms/step - loss: 0.2169 - accuracy: 0.9258 - val_loss: 0.2430 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 19/25
# 756/756 [==============================] - 249s 329ms/step - loss: 0.2182 - accuracy: 0.9267 - val_loss: 0.4502 - val_accuracy: 0.8542 - lr: 1.0000e-04
# Epoch 20/25
# 756/756 [==============================] - 251s 332ms/step - loss: 0.2004 - accuracy: 0.9296 - val_loss: 0.1360 - val_accuracy: 0.9583 - lr: 1.0000e-04
# Epoch 21/25
# 756/756 [==============================] - 251s 331ms/step - loss: 0.1943 - accuracy: 0.9331 - val_loss: 0.1974 - val_accuracy: 0.9219 - lr: 1.0000e-04
# Epoch 22/25
# 756/756 [==============================] - 259s 342ms/step - loss: 0.1899 - accuracy: 0.9377 - val_loss: 0.4558 - val_accuracy: 0.8177 - lr: 1.0000e-04
# Epoch 23/25
# 756/756 [==============================] - 255s 337ms/step - loss: 0.1715 - accuracy: 0.9439 - val_loss: 0.2837 - val_accuracy: 0.8906 - lr: 1.0000e-04
# Epoch 24/25
# 756/756 [==============================] - 251s 332ms/step - loss: 0.1712 - accuracy: 0.9436 - val_loss: 0.2960 - val_accuracy: 0.9062 - lr: 1.0000e-04
# Epoch 25/25
# 756/756 [==============================] - 250s 331ms/step - loss: 0.1853 - accuracy: 0.9391 - val_loss: 0.1515 - val_accuracy: 0.9583 - lr: 1.0000e-04

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train accuracy')
plt.plot(history.history['val_accuracy'],color='blue',label='validation accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting training and validation loss
plt.plot(history.history['loss'], color='red', label='train loss')
plt.plot(history.history['val_loss'], color='blue', label='validation loss')
plt.legend()
plt.show()

# %%
train_loss, train_accuracy = model.evaluate(train_generator)

print(f'Train accuracy: {train_accuracy:.4f}')
# Out:
# 757/757 [==============================] - 246s 324ms/step - loss: 0.0977 - accuracy: 0.9690
# Train accuracy: 0.9690

# %%
# Evaluate the model on the test data using the test generator
test_loss, test_accuracy = model.evaluate(test_generator)

print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# 131/131 [==============================] - 39s 301ms/step - loss: 0.1701 - accuracy: 0.9438
# Test accuracy: 0.9438

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Make Predictions
y_pred = model.predict(test_generator)

# Convert Predictions and True Labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = test_generator.classes

# Create the Confusion Matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)


# Create a dictionary to map class indices to class names
class_indices = test_generator.class_indices
class_names = {v: k for k, v in class_indices.items()}


# Calculate precision, recall, and F1 score for each class
precision = precision_score(y_true_classes, y_pred_classes, average=None)
recall = recall_score(y_true_classes, y_pred_classes, average=None)
f1 = f1_score(y_true_classes, y_pred_classes, average=None)

# Visualize the Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices,
            yticklabels=test_generator.class_indices)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()


# Create a list of class names
class_names_list = [class_names[i] for i in range(len(class_indices))]

# Create a DataFrame to organize the results
results_df = pd.DataFrame({
    'Class': class_names_list,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1
})

# Print the results table
print(results_df)
# Out:
# 131/131 [==============================] - 36s 251ms/step
#                               Class  Precision    Recall  F1 Score
# 0    carcinoma_in_situ_filtered_nlm   0.883792  0.969799  0.924800
# 1     light_dysplastic_filtered_nlm   0.951389  0.919463  0.935154
# 2  moderate_dysplastic_filtered_nlm   0.959259  0.872054  0.913580
# 3      normal_columnar_filtered_nlm   0.969388  0.956376  0.962838
# 4  normal_intermediate_filtered_nlm   0.996656  1.000000  0.998325
# 5   normal_superficiel_filtered_nlm   0.996633  0.996633  0.996633
# 6    severe_dysplastic_filtered_nlm   0.889610  0.922559  0.905785

# %%
# Save the model with custom layers and weights
model.save('InceptionResNetV2.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# from keras.applications import ResNet50V2

# Load the model
new_model = tf.keras.models.load_model('/content/drive/MyDrive/InceptionResNetV2.h5')

# Compile the model after unfreezing layers for fine-tuning
# new_model.compile(
#     loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),  # Use categorical_crossentropy
#     optimizer=RMSprop(learning_rate=base_learning_rate/10),
#     metrics=[tf.keras.metrics.CategoricalAccuracy(name='accuracy')]  # Use CategoricalAccuracy
# )

# # Set up callbacks
# reduce_lr = ReduceLROnPlateau(monitor='loss', patience=3, factor=0.2, min_lr=1e-6)
# early_stopping = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# # Train the new_model with early stopping and learning rate reduction
# history = new_model.fit(
#     train_generator,
#     steps_per_epoch=train_generator.samples // batch_size,
#     epochs=50,
#     initial_epoch=25,
#     validation_data=val_generator,
#     validation_steps=len(val_generator) // batch_size,
#     callbacks=[reduce_lr, early_stopping]
# )

# %%
train_loss, train_accuracy = new_model.evaluate(train_generator)

print(f'Train accuracy: {train_accuracy:.4f}')
# Out:
# 757/757 [==============================] - 221s 275ms/step - loss: 0.0989 - accuracy: 0.9670
# Train accuracy: 0.9670

# %%
# Evaluate the model on the test data using the test generator
test_loss, test_accuracy = new_model.evaluate(test_generator)

print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# 131/131 [==============================] - 36s 271ms/step - loss: 0.1474 - accuracy: 0.9482
# Test accuracy: 0.9482

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Make Predictions
y_pred = new_model.predict(test_generator)

# Convert Predictions and True Labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = test_generator.classes

# Create the Confusion Matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)


# Create a dictionary to map class indices to class names
class_indices = test_generator.class_indices
class_names = {v: k for k, v in class_indices.items()}


# Calculate precision, recall, and F1 score for each class
precision = precision_score(y_true_classes, y_pred_classes, average=None)
recall = recall_score(y_true_classes, y_pred_classes, average=None)
f1 = f1_score(y_true_classes, y_pred_classes, average=None)

# Visualize the Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices,
            yticklabels=test_generator.class_indices)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()


# Create a list of class names
class_names_list = [class_names[i] for i in range(len(class_indices))]

# Create a DataFrame to organize the results
results_df = pd.DataFrame({
    'Class': class_names_list,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1
})

# Print the results table
print(results_df)
# Out:
# 131/131 [==============================] - 36s 250ms/step
#                               Class  Precision    Recall  F1 Score
# 0    carcinoma_in_situ_filtered_nlm   0.871951  0.959732  0.913738
# 1     light_dysplastic_filtered_nlm   0.928571  0.916107  0.922297
# 2  moderate_dysplastic_filtered_nlm   0.973485  0.865320  0.916221
# 3      normal_columnar_filtered_nlm   0.966887  0.979866  0.973333
# 4  normal_intermediate_filtered_nlm   0.993311  0.996644  0.994975
# 5   normal_superficiel_filtered_nlm   0.996633  0.996633  0.996633
# 6    severe_dysplastic_filtered_nlm   0.872910  0.878788  0.875839

# %%
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Define the determine_cancerous function
def determine_cancerous(class_name):
    cancerous_classes = {
        'carcinoma_in_situ_filtered_nlm': True,
        'light_dysplastic_filtered_nlm': True,
        'moderate_dysplastic_filtered_nlm': True,
        'normal_columnar_filtered_nlm': False,
        'normal_intermediate_filtered_nlm':False,
        'normal_superficiel_filtered_nlm': False,
        'severe_dysplastic_filtered_nlm': True,
    }

    return cancerous_classes.get(class_name, None)

# Load and preprocess a sample image
image_path = '/content/cervix-cancer-Deep-learning/Herlev Dataset resized/test/normal_superficiel/157183412-157183638-001 - Copy (2).BMP'
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.  # rescale

# Make a prediction
prediction = new_model.predict(img_array)

# Convert the prediction to class name
class_index = np.argmax(prediction)
class_name = list(test_generator.class_indices.keys())[class_index]

plt.imshow(img)
plt.show()

# Print the predicted class name
print(f'Predicted Class: {class_name}')

# Determine if it's cancerous or not
is_cancerous = determine_cancerous(class_name)



# Print whether it's cancerous or not
if is_cancerous is not None:
    if is_cancerous:
        print('Cancerous')
    else:
        print('Non-cancerous')
else:
    print('Class not found in dictionary')

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Define the NLM filter function
def nlm_filter(image):
    filtered_image = cv2.fastNlMeansDenoisingColored(image, None, 10, 10, 7, 21)  # Adjust parameters as needed
    return filtered_image


# Define the determine_cancerous function
def determine_cancerous(class_name):
    cancerous_classes = {
        'carcinoma_in_situ_filtered_nlm': True,
        'light_dysplastic_filtered_nlm': True,
        'moderate_dysplastic_filtered_nlm': True,
        'normal_columnar_filtered_nlm': False,
        'normal_intermediate_filtered_nlm': False,
        'normal_superficiel_filtered_nlm': False,
        'severe_dysplastic_filtered_nlm': True,
    }
    return cancerous_classes.get(class_name, None)

# Load and preprocess a sample image
image_path = '/content/cervix-cancer-Deep-learning/Herlev Dataset resized/test/normal_superficiel/157222737-157222750-002 - Copy (2).BMP'  # Replace with the actual path to your image
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB


filtered_image = nlm_filter(img_rgb)

# Display the filtered image
plt.imshow(filtered_image)
# plt.title('Filtered Image')
plt.show()

# Rescale and expand dimensions
img_array = np.expand_dims(filtered_image / 255., axis=0)

# Make a prediction
prediction = new_model.predict(img_array)

# Convert the prediction to class name
class_index = np.argmax(prediction)
class_name = list(test_generator.class_indices.keys())[class_index]

# Print the predicted class name
print(f'Predicted Class: {class_name}')

# Determine if it's cancerous or not
is_cancerous = determine_cancerous(class_name)

# Print whether it's cancerous or not
if is_cancerous is not None:
    if is_cancerous:
        print('Cancerous')
    else:
        print('Non-cancerous')
else:
    print('Class not found in dictionary')
